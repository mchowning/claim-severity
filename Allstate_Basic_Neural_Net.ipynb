# %%
# %pylab inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
full_data = pd.read_csv('data/train.csv')

# %%
full_y = full_data.loss
full_X = full_data.drop(['loss'], axis=1)


#full_train, test = train_test_split()

# %%
# Encode cate

cat_col = full_X.filter(regex='^cat.*$', axis=1)
cat_col.apply(LabelEncoder().fit_transform)
cat_col
#full_X.filter(regex='^cat.*$', axis=1).apply(LabelEncoder().fit_transform)
# Out:
#        cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10  ...   cat107  \
# 0         A    B    A    B    A    A    A    A    B     A  ...        J
# 1         A    B    A    A    A    A    A    A    B     B  ...        K
# 2         A    B    A    A    B    A    A    A    B     B  ...        F
# 3         B    B    A    B    A    A    A    A    B     A  ...        K
# 4         A    B    A    B    A    A    A    A    B     B  ...        G
# 5         A    B    A    A    A    A    A    A    B     A  ...        F
# 6         A    A    A    A    B    A    A    A    A     A  ...        F
# 7         A    B    A    B    A    A    A    A    B     A  ...        I
# 8         A    B    B    B    B    A    A    A    B     B  ...        M
# 9         A    B    A    A    B    B    A    A    B     A  ...        J
# 10        A    B    A    A    A    A    A    A    B     B  ...        F
# 11        A    B    A    A    B    A    A    A    B     B  ...        F
# ...
